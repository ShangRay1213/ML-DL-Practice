# %%
#  File: linear_regression_one_varialbe.ipynb
#  ----------------------------
#  This file shows students the fundamental concepts of 
#  machine learing:
#      - loss function
#      - cost function
#      - linear regression
#      - training process

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# This function computes the L2 loss which is 
# ----------------------------------------
# [sum of (theta*x_i - y_i)^2] / (2*m)
# ----------------------------------------
# of data (x, y) to the line y = theta*x
# 
# x: list, containing 21 data points
# y: list, containing 21 data points
# theta: float, slope of the line
# return: float, the sum over all L2 loss of data points

def cost_function(theta, x, y):
    return sum( (theta*x[i]-y[i])**2 for i in range(len(x)))/ (2*len(x))

# %%
# You should see 2.3333333333333335
print(cost_function(1.1, [0, 0, 0], [1, 2, 3]))
# Out:
# 2.3333333333333335

# %%
# This function returns the partial derivative of L2 loss function relative to theta: 
# --------------------------------------
# [sum of (theta*x_i - y_i) * (x_i)] / m
# --------------------------------------
# x: list, containing 21 data points
# y: list, containing 21 data points
# theta: float, slope of the line
# return: flaot, the sum over dJ_dtheta over all data points

def dJ_dtheta(theta, x, y):
    return sum((theta*x[i]-y[i])*x[i] for i in range(len(x))) / len(x)

# %%
# You should see 0.46666666666666706
print(dJ_dtheta(1.1, [1, 2, 3], [1, 2, 3]))
# Out:
# 0.46666666666666706

# %%
# ---------- DO NOT EDIT THE CODE BELOW THIS LINE ---------- #

# %%
x = [6.1101,5.5277,8.5186,7.0032,5.8598,8.3829,7.4764,8.5781,6.4862,5.0546,5.7107,10.164,5.734,8.4084,5.6407,5.3794,6.3654,5.1301,6.4296,7.0708,6.1891]

# %%
y = [6.592,9.1302,13.662,11.854,6.8233,11.886,4.3483,12,6.5987,3.8166,3.2522,15.505,3.1551,7.2258,0.71618,3.5129,5.3048,0.56077,3.6518,5.3893,3.1386]

# %%
# ---------- Showing your data ---------- #

# %%
plt.scatter(x, y)
axes = plt.gca()
axes.set_xlim([0,12])
axes.set_ylim([0,30])
# Out:
# (0.0, 30.0)

# %%
# ---------- Initialize your theta ---------- #

# %%
theta = 4

# %%
# ---------- Initialize your alpha ---------- #

# %%
# TODO: which value is appropriate for an ideal alpha?

# %%
alpha = 0.01

# %%
# ---------- Training process ---------- #
# ---- 11 iterations over all data ----- #

# %%
theta_history = []
cost_history = []
for i in range(100):
    theta_history.append(theta)
    cost = cost_function(theta, x, y)
    cost_history.append(cost)

    #Gradient Descent
    theta = theta - alpha * dJ_dtheta(theta, x, y)

# %%
# ---------- Theta changes during training process ---------- #

# %%
print(cost_history)
# Out:
# [5.009627416040286, 5.009627415934495, 5.009627415904829, 5.00962741589651, 5.009627415894177, 5.009627415893522, 5.0096274158933385, 5.009627415893287, 5.009627415893274, 5.00962741589327, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893268, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893268, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267]

# %%
theta = theta_history[0]

print(f'theta: {theta}')

x_plot = np.linspace(0, 12, 140)
y_plot = theta*x_plot


plt.scatter(x_plot, y_plot, s=8, color='red')
plt.scatter(x, y, color='blue')

plt.title("0 iterations", color='red', fontdict = {'fontsize': 20})
plt.show()
# Out:
# theta: 1.035398403239218

# %%
theta = theta_history[1]

print(f'theta: {theta}')

x_plot = np.linspace(0, 12, 140)
y_plot = theta*x_plot


plt.scatter(x_plot, y_plot, s=8, color='red')
plt.scatter(x, y, color='blue')

plt.title("1 iterations", color='red', fontdict = {'fontsize': 20})
plt.show()
# Out:
# theta: 1.0353972271039158

# %%
theta = theta_history[2]

print(f'theta: {theta}')

x_plot = np.linspace(0, 12, 140)
y_plot = theta*x_plot


plt.scatter(x_plot, y_plot, s=8, color='red')
plt.scatter(x, y, color='blue')

plt.title("2 iterations", color='red', fontdict = {'fontsize': 20})
plt.show()
# Out:
# theta: 1.0353966042798373

# %%
theta = theta_history[3]

print(f'theta: {theta}')

x_plot = np.linspace(0, 12, 140)
y_plot = theta*x_plot


plt.scatter(x_plot, y_plot, s=8, color='red')
plt.scatter(x, y, color='blue')

plt.title("3 iterations", color='red', fontdict = {'fontsize': 20})
plt.show()

# %%
theta = theta_history[4]

print(f'theta: {theta}')

x_plot = np.linspace(0, 12, 140)
y_plot = theta*x_plot


plt.scatter(x_plot, y_plot, s=8, color='red')
plt.scatter(x, y, color='blue')

plt.title("4 iterations", color='red', fontdict = {'fontsize': 20})
plt.show()

# %%
theta = theta_history[5]

print(f'theta: {theta}')

x_plot = np.linspace(0, 12, 140)
y_plot = theta*x_plot


plt.scatter(x_plot, y_plot, s=8, color='red')
plt.scatter(x, y, color='blue')

plt.title("5 iterations", color='red', fontdict = {'fontsize': 20})
plt.show()

# %%
theta = theta_history[-1]

print(f'theta: {theta}')

x_plot = np.linspace(0, 12, 140)
y_plot = theta*x_plot


plt.scatter(x_plot, y_plot, s=8, color='red')
plt.scatter(x, y, color='blue')

plt.title("10 iterations", color='red', fontdict = {'fontsize': 20})
plt.show()

# %%
# ---------- Plot the errors over the training process ---------- #

# %%
plot_x = list(range(len(cost_history)))
plot_y = cost_history
plt.plot(plot_x, plot_y)
plt.title("Costs over iterations", color = 'blue', fontdict = {'fontsize': 20})
# Out:
# Text(0.5, 1.0, 'Costs over iterations')

# %%
print('####################################################')
print(f'###### Final theta learned: {theta_history[-1]} ######')
print('####################################################')
# Out:
# ####################################################
# ###### Final theta learned: 1.0353959032099578 ######
# ####################################################
